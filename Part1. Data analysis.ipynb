# %% [markdown]
# # Import Libraries

# %%
import cv2
import numpy as np
import pandas as pd

# %% [markdown]
# # Data path setting & analysis

# %%
IMAGE_PATH = '/data/backup/pervinco_2020/datasets/plant-pathology-2020-fgvc7/images/'
TEST_PATH = '/data/backup/pervinco_2020/datasets/plant-pathology-2020-fgvc7/test.csv'
TRAIN_PATH = '/data/backup/pervinco_2020/datasets/plant-pathology-2020-fgvc7/train.csv'
SUB_PATH = '/data/backup/pervinco_2020/datasets/plant-pathology-2020-fgvc7/sample_submission.csv'

# %%
sub = pd.read_csv(SUB_PATH)
test_data = pd.read_csv(TEST_PATH)
train_data = pd.read_csv(TRAIN_PATH)

# %%
train_data.head()
# Out:
#   image_id  healthy  multiple_diseases  rust  scab
# 0  Train_0        0                  0     0     1
# 1  Train_1        0                  1     0     0
# 2  Train_2        1                  0     0     0
# 3  Train_3        0                  0     1     0
# 4  Train_4        1                  0     0     0

# %%
test_data.head()
# Out:
#   image_id
# 0   Test_0
# 1   Test_1
# 2   Test_2
# 3   Test_3
# 4   Test_4

# %%
# import to show progress bar
from tqdm import tqdm
tqdm.pandas()

SAMPLE_LEN = 100

def load_image(image_id):
    file_path = image_id + ".jpg"
    image = cv2.imread(IMAGE_PATH + file_path)
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

train_images = train_data["image_id"][:SAMPLE_LEN].progress_apply(load_image)
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 47.80it/s]

# %%
# python visualization tool
import plotly.express as px

fig = px.imshow(cv2.resize(train_images[0], (205, 136)))
fig.show()
# Out:
# <div>
#
#
#             <div id="810821b3-02f8-4577-91ef-cf1e1a4266c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("810821b3-02f8-4577-91ef-cf1e1a4266c0")) {
#                     Plotly.newPlot(
#                         '810821b3-02f8-4577-91ef-cf1e1a4266c0',
#                         [{"hovertemplate": "x: %{x}<br>y: %{y}<br>color: %{z}<extra></extra>", "type": "image", "z": [[[33, 51, 13], [35, 53, 15], [35, 56, 15], [39, 57, 15], [41, 59, 17], [44, 62, 20], [44, 62, 20], [46, 64, 22], [47, 69, 23], [47, 69, 23], [47, 69, 23], [45, 67, 21], [46, 68, 22], [46, 68, 22], [48, 66, 24], [47, 65, 23], [45, 66, 23], [43, 64, 21], [43, 61, 19], [48, 66, 24], [58, 70, 30], [65, 73, 34], [87, 87, 49], [104, 97, 61], [117, 103, 74], [133, 112, 91], [145, 120, 97], [146, 120, 103], [144, 118, 101], [136, 116, 92], [129, 109, 85], [118, 104, 78], [108, 94, 67], [101, 88, 61], [90, 85, 53], [80, 81, 49], [66, 66, 40], [54, 59, 32], [49, 55, 30], [46, 51, 28], [45, 54, 25], [44, 53, 24], [42, 51, 22], [42, 53, 20], [45, 56, 24], [46, 55, 24], [46, 55, 24], [46, 55, 24], [47, 56, 27], [40, 55, 24], [38, 54, 25], [37, 54, 22], [38, 55, 23], [38, 55, 23], [36, 54, 21], [36, 53, 21], [34, 50, 21], [31, 47, 18], [
, 30], [68, 74, 36], [76, 80, 44], [93, 91, 58], [107, 98, 69], [121, 107, 78], [134, 113, 92], [139, 113, 96], [139, 113, 96], [137, 111, 94], [126, 109, 84], [121, 103, 79], [112, 99, 73], [100, 93, 64], [94, 87, 58], [91, 86, 54], [83, 83, 51], [68, 67, 42], [62, 62, 36], [56, 63, 32], [54, 61, 30], [54, 64, 30], [56, 66, 32], [60, 68, 34], [64, 71, 37], [66, 73, 39], [63, 73, 38], [57, 67, 32], [54, 64, 29], [51, 60, 30], [41, 56, 25], [37, 53, 24], [36, 53, 21], [37, 54, 22], [37, 54, 22], [36, 53, 21], [36, 53, 21], [33, 49, 20], [30, 46, 17], [31, 44, 16], [27, 40, 14], [27, 40, 14], [24, 36, 12], [24, 36, 12], [23, 35, 11], [24, 36, 12], [23, 35, 11], [23 ...

# %% [markdown]
# Sample data들 중 첫번째 이미지를 ploting해서 이미지를 출력했다. RGB값은 이미지 위로 마우스 포인터를 올려 볼 수 있다.
# 이미지의 녹색 부분은 Blue channel 값이 매우 낮으나, 갈색 부분은 Blue channel 값이 높은 것을 확인 할 수 있다.
# 이는 이미지의 녹색(건강한)부분이 파란색 값이 낮고, 건강하지 않은 부분은 파란색 값이 높을 수 있다는 가능성을 나타낸다.
# 이것은 파란색 채널이 식물의 질병을 감지하는 열쇠가 될 수 있음을 시사한다.

# %% [markdown]
# ## Channel Distributions

# %%
red_values = [np.mean(train_images[idx][:, :, 0]) for idx in range(len(train_images))]
green_values = [np.mean(train_images[idx][:, :, 1]) for idx in range(len(train_images))]
blue_values = [np.mean(train_images[idx][:, :, 2]) for idx in range(len(train_images))]
values = [np.mean(train_images[idx]) for idx in range(len(train_images))]

# %%
import plotly.figure_factory as ff

fig = ff.create_distplot([values], group_labels=["Channels"], colors=["purple"])
fig.update_layout(showlegend=False, template="simple_white")
fig.update_layout(title_text="Distribution of channel values")
fig.data[0].marker.line.color = 'rgb(0, 0, 0)'
fig.data[0].marker.line.width = 0.5
fig
# Out:
# <div>
#
#
#             <div id="18f1850a-00db-4e63-9496-096aa76c0a3f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("18f1850a-00db-4e63-9496-096aa76c0a3f")) {
#                     Plotly.newPlot(
#                         '18f1850a-00db-4e63-9496-096aa76c0a3f',
#                         [{"autobinx": false, "histnorm": "probability density", "legendgroup": "Channels", "marker": {"color": "purple", "line": {"color": "rgb(0, 0, 0)", "width": 0.5}}, "name": "Channels", "opacity": 0.7, "type": "histogram", "x": [96.78047626201923, 121.86944969093406, 119.85802140567766, 123.12914544223138, 94.97350844684829, 122.34518288785867, 107.56065538194444, 117.22863247863248, 88.49503980177808, 84.94999213026557, 88.09666490193834, 112.4602294623779, 116.19681430765415, 116.71978808951465, 97.66587718921703, 104.30341307997558, 114.86390403216575, 108.52025514632936, 115.14197346707113, 98.14654304029304, 108.8071054162851, 88.89801372672467, 109.7264401614011, 101.3494374332265, 91.52952974759616, 110.31417303399725, 98.5584940666972, 126.4974127651862, 115.01896749084